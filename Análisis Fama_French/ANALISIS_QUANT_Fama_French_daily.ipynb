# %% [markdown]
# ## **Análisis Cuantitativo del Impacto de los Flujos de Capital hacia ETFs en la Valoración del S&P500**

# %% [markdown]
# Este estudio tiene como objetivo realizar una contribución significativa a la investigación financiera existente. Mediante la expansión del modelo Fama-French, busca explorar la influencia de los flujos de fondos —específicamente, el capital que entra y sale de los fondos de inversión que tienen participaciones en Apple— en los rendimientos de las acciones de la empresa.
#
# El modelo ampliado se formula de la siguiente manera:
#
#
# R_{apple,t} - R_{f,t} = \alpha + \beta_m(R_{m,t} - R_{f,t}) + \beta_sSMB_t + \beta_hHML_t + \beta_fFF_t + \epsilon_t
#
# Donde:
# - `R_{apple,t} - R_{f,t}` es el exceso de rendimiento de las acciones de Apple sobre la tasa libre de riesgo en el tiempo t.
# - `\alpha` es el término de intercepción del modelo.
# - `\beta_m, \beta_s, \beta_h, \beta_f` son los coeficientes de sensibilidad a los factores de mercado, tamaño, valor, y flujos de fondos, respectivamente.
# - `R_{m,t} - R_{f,t}` representa el exceso de rendimiento del mercado.
# - `SMB_t` y `HML_t` son los factores de tamaño y valor del modelo Fama-French.
# - `FF_t` es el factor adicional de flujos de fondos propuesto.
# - `\epsilon_t` es el término de error.
#
#
#
# Este enfoque permite evaluar si los flujos monetarios hacia o desde fondos de inversión ejercen una influencia significativa en la valoración de Apple, aportando una nueva dimensión al análisis tradicional de rendimientos de acciones.

# %%
import pandas as pd
import statsmodels.api as sm

# Cargar el CSV en un DataFrame
df = pd.read_csv('/content/Book1.csv', sep = ';')

print(df)
# Out:
#             Date Mkt-RF    SMB    HML     RF rendimientos apple % Fundflows
# 0     03/01/2018   0,59  -0,39  -0,18  0,60%             0,631%     -0,077%
# 1     04/01/2018   0,42  -0,26   0,24  0,60%             0,421%     -0,363%
# 2     05/01/2018   0,66  -0,35  -0,26  0,60%             0,664%     -0,193%
# 3     08/01/2018   0,19  -0,15   0,05  0,60%             0,183%     -0,461%
# 4     09/01/2018   0,15  -0,35  -0,04  0,60%             0,226%      0,821%
# ...          ...    ...    ...    ...    ...                ...         ...
# 1509  21/12/2023   0,34  -0,43  -0,88  0,00%             0,944%      0,277%
# 1510  22/12/2023   1,55   1,72   1,35  0,00%             0,201%      0,492%
# 1511  26/12/2023   0,51   1,12   2,05  0,00%             0,421%      0,510%
# 1512  27/12/2023  -0,06   -0,4  -0,57  0,00%             0,181%      0,195%
# 1513  28/12/2023   0,42  -0,38  -0,38  0,00%             0,038%      0,314%
#
# [1514 rows x 7 columns]

# %%
import pandas as pd


# Spanish month abbreviations to English
spanish_months = {
    'ene': 'Jan', 'feb': 'Feb', 'mar': 'Mar', 'abr': 'Apr', 'may': 'May', 'jun': 'Jun',
    'jul': 'Jul', 'ago': 'Aug', 'sep': 'Sep', 'oct': 'Oct', 'nov': 'Nov', 'dic': 'Dec'
}

# Replace the Spanish month abbreviations with English abbreviations
df['Date'] = df['Date'].replace(spanish_months, regex=True)

print(df)
# Out:
#             Date Mkt-RF    SMB    HML     RF rendimientos apple % Fundflows
# 0     03/01/2018   0,59  -0,39  -0,18  0,60%             0,631%     -0,077%
# 1     04/01/2018   0,42  -0,26   0,24  0,60%             0,421%     -0,363%
# 2     05/01/2018   0,66  -0,35  -0,26  0,60%             0,664%     -0,193%
# 3     08/01/2018   0,19  -0,15   0,05  0,60%             0,183%     -0,461%
# 4     09/01/2018   0,15  -0,35  -0,04  0,60%             0,226%      0,821%
# ...          ...    ...    ...    ...    ...                ...         ...
# 1509  21/12/2023   0,34  -0,43  -0,88  0,00%             0,944%      0,277%
# 1510  22/12/2023   1,55   1,72   1,35  0,00%             0,201%      0,492%
# 1511  26/12/2023   0,51   1,12   2,05  0,00%             0,421%      0,510%
# 1512  27/12/2023  -0,06   -0,4  -0,57  0,00%             0,181%      0,195%
# 1513  28/12/2023   0,42  -0,38  -0,38  0,00%             0,038%      0,314%
#
# [1514 rows x 7 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])
print(df.columns)
print(df)
print(df.dtypes)
format='%b-%Y'
# Out:
# Index(['Date', 'Mkt-RF', 'SMB', 'HML', 'RF', 'rendimientos apple',
#        '% Fundflows'],
#       dtype='object')
#            Date Mkt-RF    SMB    HML     RF rendimientos apple % Fundflows
# 0    2018-03-01   0,59  -0,39  -0,18  0,60%             0,631%     -0,077%
# 1    2018-04-01   0,42  -0,26   0,24  0,60%             0,421%     -0,363%
# 2    2018-05-01   0,66  -0,35  -0,26  0,60%             0,664%     -0,193%
# 3    2018-08-01   0,19  -0,15   0,05  0,60%             0,183%     -0,461%
# 4    2018-09-01   0,15  -0,35  -0,04  0,60%             0,226%      0,821%
# ...         ...    ...    ...    ...    ...                ...         ...
# 1509 2023-12-21   0,34  -0,43  -0,88  0,00%             0,944%      0,277%
# 1510 2023-12-22   1,55   1,72   1,35  0,00%             0,201%      0,492%
# 1511 2023-12-26   0,51   1,12   2,05  0,00%             0,421%      0,510%
# 1512 2023-12-27  -0,06   -0,4  -0,57  0,00%             0,181%      0,195%
# 1513 2023-12-28   0,42  -0,38  -0,38  0,00%             0,038%      0,314%
#
# [1514 rows x 7 columns]
# Date                  datetime64[ns]
# Mkt-RF                        object
# SMB                           object
# HML                           object
# RF                            object
# rendimientos apple            object
# % Fundflows                   object
# dtype: object
# <ipython-input-33-e484e2d9e6ef>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])

# %%
# Eliminar la última fila utilizando .drop() y iloc
df.drop(df.iloc[-1].name, inplace=True)



# Verifica tu DataFrame
print(df)

# Verifica los cambios
print(df.head())
print(df.dtypes)
# Out:
#            Date Mkt-RF    SMB    HML     RF rendimientos apple % Fundflows
# 0    2018-03-01   0,59  -0,39  -0,18  0,60%             0,631%     -0,077%
# 1    2018-04-01   0,42  -0,26   0,24  0,60%             0,421%     -0,363%
# 2    2018-05-01   0,66  -0,35  -0,26  0,60%             0,664%     -0,193%
# 3    2018-08-01   0,19  -0,15   0,05  0,60%             0,183%     -0,461%
# 4    2018-09-01   0,15  -0,35  -0,04  0,60%             0,226%      0,821%
# ...         ...    ...    ...    ...    ...                ...         ...
# 1508 2023-12-20   0,34  -0,39  -0,12  0,00%            -1,395%      0,246%
# 1509 2023-12-21   0,34  -0,43  -0,88  0,00%             0,944%      0,277%
# 1510 2023-12-22   1,55   1,72   1,35  0,00%             0,201%      0,492%
# 1511 2023-12-26   0,51   1,12   2,05  0,00%             0,421%      0,510%
# 1512 2023-12-27  -0,06   -0,4  -0,57  0,00%             0,181%      0,195%
#
# [1513 rows x 7 columns]
#         Date Mkt-RF    SMB    HML     RF rendimientos apple % Fundflows
# 0 2018-03-01   0,59  -0,39  -0,18  0,60%             0,631%     -0,077%
# 1 2018-04-01   0,42  -0,26   0,24  0,60%             0,421%     -0,363%
# 2 2018-05-01   0,66  -0,35  -0,26  0,60%             0,664%     -0,193%
# 3 2018-08-01   0,19  -0,15   0,05  0,60%             0,183%     -0,461%
# 4 2018-09-01   0,15  -0,35  -0,04  0,60%             0,226%      0,821%
# Date                  datetime64[ns]
# Mkt-RF                        object
# SMB                           object
# HML                           object
# RF                            object
# rendimientos apple            object
# % Fundflows                   object
# dtype: object

# %%
# Reemplaza las comas en los números y convierte las columnas a float
df['Mkt-RF'] = df['Mkt-RF'].str.replace(',', '.').astype(float)
df['SMB'] = df['SMB'].str.replace(',', '.').astype(float)
df['HML'] = df['HML'].str.replace(',', '.').astype(float)

# Convierte las columnas de RF y rendimientos de apple de porcentaje a float
df['RF'] = df['RF'].str.rstrip('%').str.replace(',', '.').astype(float) / 100
df['rendimientos apple'] = df['rendimientos apple'].str.rstrip('%').str.replace(',', '.').astype(float) / 100

# Para % Fundflows, maneja los NaNs antes de la conversión si es necesario
df['% Fundflows'] = df['% Fundflows'].str.rstrip('%').str.replace(',', '.').astype(float) / 100

# Verifica los cambios
print(df.head())
print(df.dtypes)
# Out:
#         Date  Mkt-RF   SMB   HML     RF  rendimientos apple  % Fundflows
# 0 2018-03-01    0.59 -0.39 -0.18  0.006             0.00631     -0.00077
# 1 2018-04-01    0.42 -0.26  0.24  0.006             0.00421     -0.00363
# 2 2018-05-01    0.66 -0.35 -0.26  0.006             0.00664     -0.00193
# 3 2018-08-01    0.19 -0.15  0.05  0.006             0.00183     -0.00461
# 4 2018-09-01    0.15 -0.35 -0.04  0.006             0.00226      0.00821
# Date                  datetime64[ns]
# Mkt-RF                       float64
# SMB                          float64
# HML                          float64
# RF                           float64
# rendimientos apple           float64
# % Fundflows                  float64
# dtype: object

# %%
import statsmodels.api as sm

# Preparar las variables independientes
# Añadir una constante al modelo para el término de intercepción
X = df[['Mkt-RF', 'SMB', 'HML', '% Fundflows']]
X = sm.add_constant(X)

# La variable dependiente es el exceso de rendimiento de Apple
# Asegúrate de que 'RF' y 'rendimientos apple' están en formato decimal adecuado
Y = df['rendimientos apple'] - df['RF']

# Estimar el modelo OLS
modelo = sm.OLS(Y, X).fit()

# Mostrar el resumen del modelo
print(modelo.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.413
# Model:                            OLS   Adj. R-squared:                  0.412
# Method:                 Least Squares   F-statistic:                     265.4
# Date:                Wed, 13 Mar 2024   Prob (F-statistic):          9.21e-173
# Time:                        16:09:49   Log-Likelihood:                 4765.4
# No. Observations:                1513   AIC:                            -9521.
# Df Residuals:                    1508   BIC:                            -9494.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -0.0028      0.000    -10.342      0.000      -0.003      -0.002
# Mkt-RF          0.0066      0.000     32.318      0.000       0.006       0.007
# SMB            -0.0019      0.000     -4.899      0.000      -0.003      -0.001
# HML             0.0016      0.000      6.157      0.000       0.001       0.002
# % Fundflows    -0.0095      0.043     -0.222      0.824      -0.093       0.074
# ==============================================================================
# Omnibus:                      243.448   Durbin-Watson:                   1.717
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1191.766
# Skew:                           0.666   Prob(JB):                    1.63e-259
# Kurtosis:                       7.139   Cond. No.                         215.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
