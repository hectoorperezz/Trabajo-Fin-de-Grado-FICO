# %%
tickers = ["PCG",
"TDY",
"MPWR",
"ADBE",
"APA",
"HES",
"PFE",
"TTWO",
"AWK",
"HPE",
"MAR",
"TSLA",
"CBRE",
"TER",
"UNH",
"COST",
"AMD",
"WAT",
"EA",
"RVTY",
"REGN",
"AZO",
"HD",
"KLAC",
"KEYS",
"AMAT",
"SLB",
"ETSY",
"HIG",
"INTC",
"WST",
"YUM",
"BBY",
"ZBH",
"OTIS",
"FTNT",
"ENPH",
"CCI",
"PXD",]

# %%
pip install yfinance

# %%
import yfinance as yf

# Obtener el objeto Ticker para Apple
aapl = yf.Ticker("TSLA")

# Obtener los principales tenedores institucionales
major_holders = aapl.major_holders
institutional_holders = aapl.institutional_holders

# Mostrar la información
print("Principales tenedores de acciones:")
print(major_holders)
print("\nTenedores institucionales:")
print(institutional_holders)
# Out:
# Principales tenedores de acciones:
# Breakdown                          Value
# insidersPercentHeld              0.12999
# institutionsPercentHeld          0.45792
# institutionsFloatPercentHeld     0.52634
# institutionsCount             3806.00000
#
# Tenedores institucionales:
#   Date Reported                             Holder  pctHeld     Shares  \
# 0    2023-06-30                 Vanguard Group Inc   0.0701  222486933
# 1    2023-06-30                     Blackrock Inc.   0.0586  185889398
# 2    2023-06-30           State Street Corporation   0.0328  104115390
# 3    2023-06-30      Geode Capital Management, LLC   0.0163   51656526
# 4    2023-06-30            Capital World Investors   0.0133   42272512
# 5    2023-06-30                           FMR, LLC   0.0091   28771552
# 6    2022-12-31  Norges Bank Investment Management   0.0088   28085245
# 7    2023-06-30                     Morgan Stanley   0.0088   27983350
# ...

# %%
# Out:
# None
