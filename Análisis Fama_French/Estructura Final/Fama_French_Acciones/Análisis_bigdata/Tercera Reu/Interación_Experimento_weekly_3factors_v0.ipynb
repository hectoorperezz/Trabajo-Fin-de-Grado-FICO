# %%
pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.38)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.0.3)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.25.2)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.9.4)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2023.4)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (3.17.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2024.2.2)

# %%
import yfinance as yf
import numpy as np
import pandas as pd
from datetime import datetime




def validar_y_convertir_fechas(fechas):
    """
    Convierte una lista de fechas a formato 'YYYY-MM-DD' si no están ya en ese formato.

    Parámetros:
    - fechas: Lista de fechas como cadenas.

    Retorna:
    - Lista de fechas en formato 'YYYY-MM-DD'.
    """
    fechas_convertidas = []
    for fecha in fechas:
        try:
            # Intenta parsear la fecha asumiendo el formato 'YYYY-MM-DD'
            fecha_convertida = datetime.strptime(fecha, '%Y-%m-%d')
        except ValueError:
            # Intenta otros formatos si el anterior falla
            fecha_convertida = pd.to_datetime(fecha, errors='coerce')
            if pd.isnull(fecha_convertida):
                raise ValueError(f"Fecha no reconocida: {fecha}")
        # Asegura el formato correcto
        fechas_convertidas.append(fecha_convertida.strftime('%Y-%m-%d'))
    return fechas_convertidas

def obtener_precios_logaritmicos(ticker, fechas):
    """
    Descarga los datos de precios de un ticker específico y calcula la variación logarítmica
    de los precios de cierre para las fechas dadas, y luego formatea los resultados en porcentaje.

    Parámetros:
    - ticker: El símbolo del ticker de la acción (como string).
    - fechas: Lista de fechas en formato 'YYYY-MM-DD'.

    Retorna:
    - Un DataFrame con las fechas dadas y las variaciones logarítmicas de los precios de cierre entre ellas,
      formateadas en porcentaje con el símbolo '%'.
    """
    # Descargar datos de un rango que cubra las fechas dadas
    datos = yf.download(ticker, start=min(fechas), end=max(fechas))

    # Asegurarse que las fechas son tratadas como datetime
    fechas = pd.to_datetime(fechas)

    # Reindexar los datos para incluir todas las fechas dadas, llenando hacia adelante para obtener el precio más reciente si una fecha no es un día de trading
    datos_reindexados = datos.reindex(fechas, method='bfill')

    # Seleccionar solo la columna 'Close'
    precios_cierre = datos_reindexados['Close']

    # Calcular la variación logarítmica
    variacion_log = np.log(precios_cierre).diff().dropna()

    # Convertir a porcentaje, ajustar formato decimal y añadir símbolo de porcentaje
    variacion_log_porcentaje = variacion_log.apply(lambda x: f"{x*100:.2f}".replace('.', ',') + '%')

    # Convertir el índice a DatetimeIndex y renombrarlo
    variacion_log_porcentaje.index = pd.to_datetime(variacion_log_porcentaje.index)
    variacion_log_porcentaje.index.name = 'Date'

    # Ahora crea el DataFrame
    resultado = pd.DataFrame({
        'Variacion Logaritmica': variacion_log_porcentaje.values
    }, index=variacion_log_porcentaje.index)

    return resultado

# %%
def regresion(ticker):


  fechas = ["2000-01-07", "2000-01-14", "2000-01-21", "2000-01-28", "2000-02-04", "2000-02-11", "2000-02-18", "2000-02-25", "2000-03-03", "2000-03-10", "2000-03-17", "2000-03-24", "2000-03-31", "2000-04-07", "2000-04-14", "2000-04-20", "2000-04-28", "2000-05-05", "2000-05-12", "2000-05-19", "2000-05-26", "2000-06-02", "2000-06-09", "2000-06-16", "2000-06-23", "2000-06-30", "2000-07-07", "2000-07-14", "2000-07-21", "2000-07-28", "2000-08-04", "2000-08-11", "2000-08-18", "2000-08-25", "2000-09-01", "2000-09-08", "2000-09-15", "2000-09-22", "2000-09-29", "2000-10-06", "2000-10-13", "2000-10-20", "2000-10-27", "2000-11-03", "2000-11-10", "2000-
"2023-01-27", "2023-02-03", "2023-02-10", "2023-02-17", "2023-02-24", "2023-03-03", "2023-03-10", "2023-03-17", "2023-03-24", "2023-03-31", "2023-04-06", "2023-04-14", "2023-04-21", "2023-04-28", "2023-05-05", "2023-05-12", "2023-05-19", "2023-05-26", "2023-06-02", "2023-06-09", "2023-06-16", "2023-06-23", "2023-06-30", "2023-07-07", "2023-07-14", "2023-07-21", "2023-07-28", "2023-08-04", "2023-08-11", "2023-08-18", "2023-08-25", "2023-09-01", "2023-09-08", "2023-09-15", "2023-09-22", "2023-09-29", "2023-10-06", "2023-10-13", "2023-10-20", "2023-10-27", "2023-11-03", "2023-11-10", "2023-11-17", "2023-11-24", "2023-12-01", "2023-12-08", "2023-12-15", "2023-12-22", "2023-12-29", "2024-01-05", "2024-01-12", "2024-01-19", "2024-01-26", "2024-02-02", "2024-02-09", "2024-02-16", "2024-02-23",]


  # Ejemplo de uso
  # Símbolo del ticker para Apple Inc.

  fechas = validar_y_convertir_fechas(fechas)


  df_variacion_log = obtener_precios_logaritmicos(ticker,fechas)
  df_variacion_log.head()




  famafrench_df = pd.read_csv('/content/general_csv_weekly.csv', sep = ';')


  # Convierte la columna de fecha a datetime
  famafrench_df['Date'] = pd.to_datetime(famafrench_df['Date'], format="%Y-%m-%d")

  # Si necesitas un formato específico, puedes usar el parámetro 'format'
  # df['Fecha'] = pd.to_datetime(df['Fecha'], format='%Y-%m-%d')

  # Después de convertir, establece la columna de fecha como índice si deseas
  famafrench_df.set_index('Date', inplace=True)



  famafrench_df.head()


  # Si ambos DataFrames tienen el índice de fecha correctamente configurado, puedes proceder directamente a merge
  df_combinado = famafrench_df.merge(df_variacion_log, left_index=True, right_index=True, how='outer')
  # Eliminar filas que contengan algún valor NaN
  df_combinado = df_combinado.dropna()

  # Convertir el índice de fecha a una columna regular

  df_combinado = df_combinado.round(3)

  # Asegúrate de que las columnas son tratadas como strings antes de reemplazar ',' por '.'
  df_combinado['Mkt-RF'] = df_combinado['Mkt-RF'].astype(str).str.replace(',', '.').astype(float)
  df_combinado['SMB'] = df_combinado['SMB'].astype(str).str.replace(',', '.').astype(float)
  df_combinado['HML'] = df_combinado['HML'].astype(str).str.replace(',', '.').astype(float)


  # Asegura que Pandas trate las columnas como strings antes de realizar operaciones de strings
  df_combinado['RF'] = df_combinado['RF'].astype(str).str.rstrip('%').str.replace(',', '.').astype(float) / 100
  df_combinado['Variacion Logaritmica'] = df_combinado['Variacion Logaritmica'].astype(str).str.rstrip('%').str.replace(',', '.').astype(float) / 100

  # Preparar las variables independientes
  # Añadir una constante al modelo para el término de intercepción
  X = df_combinado[['Mkt-RF', 'SMB', 'HML']]
  X = sm.add_constant(X)

  # La variable dependiente es el exceso de rendimiento de Apple
  # Asegúrate de que 'RF' y 'rendimientos apple' están en formato decimal adecuado
  Y = df_combinado['Variacion Logaritmica'] - df_combinado['RF']

  # Estimar el modelo OLS
  modelo = sm.OLS(Y, X).fit()

  # Mostrar el resumen del modelo
  print(modelo.summary())
  return df_combinado

# %%
", "BLDR", "FITB", "DOV", "GLW", "RJF", "TTWO", "BR", "NDAQ", "STT", "WDC", "MTB", "HPE", "AWK", "IRM", "SBAC", "GRMN", "ALGN", "DECK", "DTE", "STLD", "ETR", "HUBB", "ULTA", "PTC", "MOH", "CPAY", "NTAP", "AXON", "EQR", "IFF", "APTV", "BAX", "GPC", "CTRA", "STE", "BALL", "ES", "ILMN", "INVH", "BRO", "PPL", "HBAN", "WAT", "FE", "ARE", "COO", "TDY", "LVS", "CBOE", "VLTO", "FSLR", "CINF", "AEE", "TXT", "MKC", "RF", "WBD", "DRI", "PFG", "J", "OMC", "NTRS", "HOLX", "IEX", "CLX", "CNP", "LH", "JBL", "WRB", "LDOS", "AVY", "EXPE", "SYF", "DPZ", "TYL", "VTR", "MAS", "ATO", "CMS", "MRO", "STX", "EXPD", "PKG", "LUV", "TSN", "FDS", "NRG", "SWKS", "VRSN", "TER", "EG", "CE", "CFG", "AKAM", "JBHT", "CCL", "ENPH", "ESS", "BBY", "SNA", "TRMB", "ALB", "BG", "EPAM", "MAA", "POOL", "CF", "ZBRA", "K", "EQT", "CAG", "SWK", "NDSN", "LYV", "DGX", "HST", "KEY", "UAL", "VTRS", "L", "LKQ", "WBA", "PNR", "DOC", "IP", "AMCR", "KMX", "RVTY", "CRL", "MGM", "ROL", "GEN", "JKHY", "WRK", "LNT", "KIM", "TAP", "AES", "EVRG", "IPG", "EMN", "SJM", "PODD", "JNPR", "ALLE", "FFIV", "HII", "UDR", "LW", "QRVO", "NI", "CPT", "TECH", "APA", "AOS", "BBWI", "MOS", "UHS", "CTLT", "INCY", "TFX", "WYNN", "HRL", "TPR", "PAYC", "NWSA", "REG", "DAY", "AIZ", "HSIC", "SOLV", "MTCH", "GL", "BF.B", "CZR", "AAL", "BXP", "CPB", "MKTX", "CHRW", "PNW", "GNRC", "BWA", "NCLH", "RHI", "ETSY", "FOXA", "BEN", "IVZ", "FMC", "FRT", "HAS", "DVA", "CMA", "BIO", "RL", "MHK",]



# Diccionario para almacenar los modelos (o el resultado que prefieras)
resultados_modelos = {}

for ticker in lista_tickers:
    print(f"Procesando {ticker}...")
    try:
        # Ejecuta tu función de regresión para el ticker actual
        resultado = regresion(ticker)

        # Almacena el resultado en el diccionario
        resultados_modelos[ticker] = resultado
    except Exception as e:
        print(f"Error al procesar {ticker}: {e}")

# Ahora tienes todos tus resultados almacenados en resultados_modelos
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Procesando MSFT...
#            Variacion Logaritmica
# Date
# 2000-01-14                 0,73%
# 2000-01-21                -7,87%
# 2000-01-28                -5,45%
# 2000-02-04                 8,12%
# 2000-02-11                -6,42%
# ...                          ...
# 2024-01-19                 2,59%
# 2024-01-26                 1,31%
# 2024-02-02                 1,79%
# 2024-02-09                 2,24%
# 2024-02-16                -4,00%
#
# [1258 rows x 1 columns]
#             Mkt-RF   SMB   HML       RF  Variacion Logaritmica
# Date
# 2000-01-14    2.07  1.96 -1.50  0.00103                 0.0073
# 2000-01-21    0.02  6.94 -2.81  0.00103                -0.0787
# 2000-01-28   -5.71  0.17  1.75  0.00103                -0.0545
# 2000-02-04    4.46  1.26 -2.94  0.00108                 0.0812
# 2000-02-11   -1.45  6.24 -2.83  0.00108                -0.0642
# ...            ...   ...   ...      ...                    ...
# 2024-01-19    0.96 -1.40 -0.55  0.00118                 0.0259
# 2024-01-26    1.03  0.77  0.38  0.00118                 0.0131
# 2024-02-02    1.18 -1.96 -1.91  0.00106                 0.0179
# 2024-02-09    1.49  1.71 -2.17  0.00106                 0.0224
# 2024-02-16   -0.30  0.50  1.10  0.00106                -0.0400
#
# [1258 rows x 5 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.458
# Model:                            OLS   Adj. R-squared:                  0.456
# Method:                 Least Squares   F-statistic:                     352.8
# Date:                Sun, 28 Apr 2024   Prob (F-statistic):          4.40e-166
# Time:                        16:45:58   Log-Likelihood:                 2697.7
# No. Observations:                1258   AIC:                            -5387.
# Df Residuals:                    1254   BIC:                            -5367.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002      0.001      0.304      0.761      -0.001       0.002
# Mkt-RF         0.0100      0.000     30.994      0.000       0.009       0.011
# SMB           -0.0033      0.001     -5.486      0.000      -0.004      -0.002
# HML           -0.0056      0.000    -12.214      0.000      -0.007      -0.005
# ==============================================================================
# Omnibus:                      183.674   Durbin-Watson:                   2.049
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1943.402
# Skew:                          -0.276   Prob(JB):                         0.00
# Kurtosis:                       9.064   Cond. No.                         2.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Procesando AAPL...
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#            Variacion Logaritmica
# Date
# 2000-01-14                 0,94%
# 2000-01-21                10,28%
# 2000-01-28                -9,11%
# 2000-02-04                 6,08%
# 2000-02-11                 0,69%
# ...                          ...
# 2024-01-19                 2,99%
# 2024-01-26                 0,45%
# 2024-02-02                -3,47%
# 2024-02-09                 1,60%
# 2024-02-16                -3,52%
#
# [1258 rows x 1 columns]
#             Mkt-RF   SMB   HML       RF  Variacion Logaritmica
# Date
# 2000-01-14    2.07  1.96 -1.50  0.00103                 0.0094
# 2000-01-21    0.02  6.94 -2.81  0.00103                 0.1028
# 2000-01-28   -5.71  0.17  1.75  0.00103                -0.0911
# 2000-02-04    4.46  1.26 -2.94  0.00108                 0.0608
# 2000-02-11   -1.45  6.24 -2.83  0.00108                 0.0069
# ...            ...   ...   ...      ...                    ...
# 2024-01-19    0.96 -1.40 -0.55  0.00118                 0.0299
# 2024-01-26    1.03  0.77  0.38  0.00118                 0.0045
# 2024-02-02    1.18 -1.96 -1.91  0.00106                -0.0347
# 2024-02-09    1.49  1.71 -2.17  0.00106                 0.0160
# 2024-02-16   -0.30  0.50  1.10  0.00106                -0.0352
#
# [1258 rows x 5 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.304
# Model:                            OLS   Adj. R-squared:                  0.303
# Method:                 Least Squares   F-statistic:                     182.7
# Date:                Sun, 28 Apr 2024   Prob (F-statistic):           2.70e-98
# Time:                        16:45:58   Log-Likelihood:                 2134.6
# No. Observations:                1258   AIC:                            -4261.
# Df Residuals:                    1254   BIC:                            -4241.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0026      0.001      2.071      0.039       0.000       0.005
# Mkt-RF         0.0111      0.001     21.938      0.000       0.010       0.012
# SMB            0.0003      0.001      0.355      0.722      -0.001       0.002
# HML           -0.0049      0.001     -6.819      0.000      -0.006      -0.003
# ==============================================================================
# Omnibus:                     1014.221   Durbin-Watson:                   1.930
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           124495.229
# Skew:                          -2.996   Prob(JB):                         0.00
# Kurtosis:                      51.365   Cond. No.                         2.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Procesando NVDA...
#            Variacion Logaritmica
# Date
# 2000-01-14                 4,81%
# 2000-01-21                 1,83%
# 2000-01-28               -18,01%
# 2000-02-04                 8,18%
# 2000-02-11                20,92%
# ...                          ...
# 2024-01-19                 8,38%
# 2024-01-26                 2,56%
# 2024-02-02                 8,07%
# 2024-02-09                 8,64%
# 2024-02-16                 0,66%
#
# [1258 rows x 1 columns]
#             Mkt-RF   SMB   HML       RF  Variacion Logaritmica
# Date
# 2000-01-14    2.07  1.96 -1.50  0.00103                 0.0481
# 2000-01-21    0.02  6.94 -2.81  0.00103                 0.0183
# 2000-01-28   -5.71  0.17  1.75  0.00103                -0.1801
# 2000-02-04    4.46  1.26 -2.94  0.00108                 0.0818
# 2000-02-11   -1.45  6.24 -2.83  0.00108                 0.2092
# ...            ...   ...   ...      ...                    ...
# 2024-01-19    0.96 -1.40 -0.55  0.00118                 0.0838
# 2024-01-26    1.03  0.77  0.38  0.00118                 0.0256
# 2024-02-02    1.18 -1.96 -1.91  0.00106                 0.0807
# 2024-02-09    1.49  1.71 -2.17  0.00106                 0.0864
# 2024-02-16   -0.30  0.50  1.10  0.00106                 0.0066
#
# [1258 rows x 5 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.356
# Model:                            OLS   Adj. R-squared:                  0.355
# Method:                 Least Squares   F-statistic:                     231.1
# Date:                Sun, 28 Apr 2024   Prob (F-statistic):          2.34e-119
# Time:                        16:45:58   Log-Likelihood:                 1636.3
# No. Observations:                1258   AIC:                            -3265.
# Df Residuals:                    1254   BIC:                            -3244.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0028      0.002      1.524      0.128      -0.001       0.006
# Mkt-RF         0.0169      0.001     22.588      0.000       0.015       0.018
# SMB            0.0074      0.001      5.392      0.000       0.005       0.010
# HML           -0.0084      0.001     -7.874      0.000      -0.011      -0.006
# ==============================================================================
# Omnibus:                      352.731   Durbin-Watson:                   1.911
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11195.013
# Skew:                           0.632   Prob(JB):                         0.00
# Kurtosis:                      17.560   Cond. No.                         2.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [*********************100%%**********************]  1 of 1 completed
# Procesando AMZN...
#            Variacion Logaritmica
# Date
# 2000-01-14                -7,94%
# 2000-01-21                -3,46%
# 2000-01-28                -0,61%
# 2000-02-04                24,18%
# 2000-02-11                -3,07%
# ...                          ...
# 2024-01-19                 0,46%
# 2024-01-26                 2,40%
# 2024-02-02                 7,67%
# 2024-02-09                 1,52%
# 2024-02-16                -2,87%
#
# [1258 rows x 1 columns]
#             Mkt-RF   SMB   HML       RF  Variacion Logaritmica
# Date
# 2000-01-14    2.07  1.96 -1.50  0.00103                -0.0794
# 2000-01-21    0.02  6.94 -2.81  0.00103                -0.0346
# 2000-01-28   -5.71  0.17  1.75  0.00103                -0.0061
# 2000-02-04    4.46  1.26 -2.94  0.00108                 0.2418
# 2000-02-11   -1.45  6.24 -2.83  0.00108                -0.0307
# ...            ...   ...   ...      ...                    ...
# 2024-01-19    0.96 -1.40 -0.55  0.00118                 0.0046
# 2024-01-26    1.03  0.77  0.38  0.00118                 0.0240
# 2024-02-02    1.18 -1.96 -1.91  0.00106                 0.0767
# 2024-02-09    1.49  1.71 -2.17  0.00106                 0.0152
# 2024-02-16   -0.30  0.50  1.10  0.00106                -0.0287
#
# [1258 rows x 5 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.295
# Model:                            OLS   Adj. R-squared:                  0.293
# Method:                 Least Squares   F-statistic:                     175.0
# Date:                Sun, 28 Apr 2024   Prob (F-statistic):           9.03e-95
# Time:                        16:45:58   Log-Likelihood:                 1855.9
# No. Observations:                1258   AIC:                            -3704.
# Df Residuals:                    1254   BIC:                            -3683.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0014      0.002      0.878      0.380      -0.002       0.004
# Mkt-RF         0.0126      0.001     19.987      0.000       0.011       0.014
# SMB            0.0020      0.001      1.726      0.085      -0.000       0.004
# HML           -0.0087      0.001     -9.670      0.000      -0.010      -0.007
# ==============================================================================
# Omnibus:                      256.629   Durbin-Watson:                   2.122
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6336.989
# Skew:                           0.254   Prob(JB):                         0.00
# Kurtosis:                      13.984   Cond. No.                         2.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Procesando META...
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#            Variacion Logaritmica
# Date
# 2000-01-14                 0,00%
# 2000-01-21                 0,00%
# 2000-01-28                 0,00%
# 2000-02-04                 0,00%
# 2000-02-11                 0,00%
# ...                          ...
# 2024-01-19                 2,36%
# 2024-01-26                 2,75%
# 2024-02-02                18,66%
# 2024-02-09                -1,46%
# 2024-02-16                 1,11%
#
# [1258 rows x 1 columns]
#             Mkt-RF   SMB   HML       RF  Variacion Logaritmica
# Date
# 2000-01-14    2.07  1.96 -1.50  0.00103                 0.0000
# 2000-01-21    0.02  6.94 -2.81  0.00103                 0.0000
# 2000-01-28   -5.71  0.17  1.75  0.00103                 0.0000
# 2000-02-04    4.46  1.26 -2.94  0.00108                 0.0000
# 2000-02-11   -1.45  6.24 -2.83  0.00108                 0.0000
# ...            ...   ...   ...      ...                    ...
# 2024-01-19    0.96 -1.40 -0.55  0.00118                 0.0236
# 2024-01-26    1.03  0.77  0.38  0.00118                 0.0275
# 2024-02-02    1.18 -1.96 -1.91  0.00106                 0.1866
# 2024-02-09    1.49  1.71 -2.17  0.00106                -0.0146
# 2024-02-16   -0.30  0.50  1.10  0.00106                 0.0111
#
# [1258 rows x 5 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.102
# Model:                            OLS   Adj. R-squared:                  0.100
# Method:                 Least Squares   F-statistic:                     47.42
# Date:                Sun, 28 Apr 2024   Prob (F-statistic):           4.95e-29
# Time:                        16:45:58   Log-Likelihood:                 2425.6
# No. Observations:                1258   AIC:                            -4843.
# Df Residuals:                    1254   BIC:                            -4823.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0013      0.001      1.258      0.209      -0.001       0.003
# Mkt-RF         0.0042      0.000     10.553      0.000       0.003       0.005
# SMB           -0.0004      0.001     -0.558      0.577      -0.002       0.001
# HML           -0.0033      0.001     -5.791      0.000      -0.004      -0.002
# ==============================================================================
# Omnibus:                      275.203   Durbin-Watson:                   1.993
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10203.014
# Skew:                           0.009   Prob(JB):                         0.00
# Kurtosis:                      16.952   Cond. No.                         2.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Procesando GOOGL...
#            Variacion Logaritmica
# Date
# 2000-01-14                 0,00%
# 2000-01-21                 0,00%
# 2000-01-28                 0,00%
# 2000-02-04                 0,00%
# 2000-02-11                 0,00%
# ...                          ...
# 2024-01-19                 2,58%
# 2024-01-26                 3,89%
# 2024-02-02                -6,66%
# 2024-02-09                 4,54%
# 2024-02-16                -5,86%
#
# [1258 rows x 1 columns]
#             Mkt-RF   SMB   HML       RF  Variacion Logaritmica
# Date
# 2000-01-14    2.07  1.96 -1.50  0.00103                 0.0000
# 2000-01-21    0.02  6.94 -2.81  0.00103                 0.0000
# 2000-01-28   -5.71  0.17  1.75  0.00103                 0.0000
# 2000-02-04    4.46  1.26 -2.94  0.00108                 0.0000
# 2000-02-11   -1.45  6.24 -2.83  0.00108                 0.0000
# ...            ...   ...   ...      ...                    ...
# 2024-01-19    0.96 -1.40 -0.55  0.00118                 0.0258
# 2024-01-26    1.03  0.77  0.38  0.00118                 0.0389
# 2024-02-02    1.18 -1.96 -1.91  0.00106                -0.0666
# 2024-02-09    1.49  1.71 -2.17  0.00106                 0.0454
# 2024-02-16   -0.30  0.50  1.10  0.00106                -0.0586
#
# [1258 rows x 5 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.296
# Model:                            OLS   Adj. R-squared:                  0.294
# Method:                 Least Squares   F-statistic:                     175.5
# Date:                Sun, 28 Apr 2024   Prob (F-statistic):           5.34e-95
# Time:                        16:45:58   Log-Likelihood:                 2564.6
# No. Observations:                1258   AIC:                            -5121.
# Df Residuals:                    1254   BIC:                            -5101.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0019      0.001      2.088      0.037       0.000       0.004
# Mkt-RF         0.0080      0.000     22.425      0.000       0.007       0.009
# SMB           -0.0008      0.001     -1.144      0.253      -0.002       0.001
# HML           -0.0017      0.001     -3.314      0.001      -0.003      -0.001
# ==============================================================================
# Omnibus:                      186.565   Durbin-Watson:                   2.089
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1307.817
# Skew:                           0.473   Prob(JB):                    1.03e-284
# Kurtosis:                       7.905   Cond. No.                         2.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Procesando GOOG...
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK.B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#            Variacion Logaritmica
# Date
# 2000-01-14                 0,00%
# 2000-01-21                 0,00%
# 2000-01-28                 0,00%
# 2000-02-04                 0,00%
# 2000-02-11                 0,00%
# ...                          ...
# 2024-01-19                 2,55%
# 2024-01-26                 3,86%
# 2024-02-02                -6,90%
# 2024-02-09                 4,55%
# 2024-02-16                -5,80%
#
# [1258 rows x 1 columns]
#             Mkt-RF   SMB   HML       RF  Variacion Logaritmica
# Date
# 2000-01-14    2.07  1.96 -1.50  0.00103                 0.0000
# 2000-01-21    0.02  6.94 -2.81  0.00103                 0.0000
# 2000-01-28   -5.71  0.17  1.75  0.00103                 0.0000
# 2000-02-04    4.46  1.26 -2.94  0.00108                 0.0000
# 2000-02-11   -1.45  6.24 -2.83  0.00108                 0.0000
# ...            ...   ...   ...      ...                    ...
# 2024-01-19    0.96 -1.40 -0.55  0.00118                 0.0255
# 2024-01-26    1.03  0.77  0.38  0.00118                 0.0386
# 2024-02-02    1.18 -1.96 -1.91  0.00106                -0.0690
# 2024-02-09    1.49  1.71 -2.17  0.00106                 0.0455
# 2024-02-16   -0.30  0.50  1.10  0.00106                -0.0580
#
# [1258 rows x 5 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.295
# Model:                            OLS   Adj. R-squared:                  0.294
# Method:                 Least Squares   F-statistic:                     175.1
# Date:                Sun, 28 Apr 2024   Prob (F-statistic):           7.80e-95
# Time:                        16:45:58   Log-Likelihood:                 2560.6
# No. Observations:                1258   AIC:                            -5113.
# Df Residuals:                    1254   BIC:                            -5093.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0019      0.001      2.094      0.036       0.000       0.004
# Mkt-RF         0.0081      0.000     22.419      0.000       0.007       0.009
# SMB           -0.0008      0.001     -1.248      0.212      -0.002       0.000
# HML           -0.0017      0.001     -3.368      0.001      -0.003      -0.001
# ==============================================================================
# Omnibus:                      194.238   Durbin-Watson:                   2.095
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1413.288
# Skew:                           0.493   Prob(JB):                    1.28e-307
# Kurtosis:                       8.098   Cond. No.                         2.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Procesando BRK.B...
# Empty DataFrame
# Columns: [Variacion Logaritmica]
# Index: []
# Empty DataFrame
# Columns: [Mkt-RF, SMB, HML, RF, Variacion Logaritmica]
# Index: []
# Error al procesar BRK.B: zero-size array to reduction operation maximum which has no identity
# Procesando LLY...
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#            Variacion Logaritmica
# Date
# 2000-01-14                -3,95%
# 2000-01-21                -5,36%
# 2000-01-28                 0,86%
# 2000-02-04                -0,67%
# 2000-02-11                -5,14%
# ...                          ...
# 2024-01-19                -2,26%
# 2024-01-26                 1,68%
# 2024-02-02                 4,35%
# 2024-02-09                10,31%
# 2024-02-16                 5,51%
#
# [1258 rows x 1 columns]
#             Mkt-RF   SMB   HML       RF  Variacion Logaritmica
# Date
# 2000-01-14    2.07  1.96 -1.50  0.00103                -0.0395
# 2000-01-21    0.02  6.94 -2.81  0.00103                -0.0536
# 2000-01-28   -5.71  0.17  1.75  0.00103                 0.0086
# 2000-02-04    4.46  1.26 -2.94  0.00108                -0.0067
# 2000-02-11   -1.45  6.24 -2.83  0.00108                -0.0514
# ...            ...   ...   ...      ...                    ...
# 2024-01-19    0.96 -1.40 -0.55  0.00118                -0.0226
# 2024-01-26    1.03  0.77  0.38  0.00118                 0.0168
# 2024-02-02    1.18 -1.96 -1.91  0.00106                 0.0435
# 2024-02-09    1.49  1.71 -2.17  0.00106                 0.1031
# 2024-02-16   -0.30  0.50  1.10  0.00106                 0.0551
#
# [1258 rows x 5 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.210
# Model:                            OLS   Adj. R-squared:                  0.208
# Method:                 Least Squares   F-statistic:                     110.8
# Date:                Sun, 28 Apr 2024   Prob (F-statistic):           1.21e-63
# Time:                        16:45:59   Log-Likelihood:                 2524.1
# No. Observations:                1258   AIC:                            -5040.
# Df Residuals:                    1254   BIC:                            -5020.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0009      0.001      0.938      0.348      -0.001       0.003
# Mkt-RF         0.0067      0.000     18.098      0.000       0.006       0.007
# SMB           -0.0044      0.001     -6.466      0.000      -0.006      -0.003
# HML           -0.0015      0.001     -2.834      0.005      -0.003      -0.000
# ==============================================================================
# Omnibus:                      310.533   Durbin-Watson:                   1.932
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6704.292
# Skew:                          -0.591   Prob(JB):                         0.00
# Kurtosis:                      14.248   Cond. No.                         2.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Procesando AVGO...
#            Variacion Logaritmica
# Date
# 2000-01-14                 0,00%
# 2000-01-21                 0,00%
# 2000-01-28                 0,00%
# 2000-02-04                 0,00%
# 2000-02-11                 0,00%
# ...                          ...
# 2024-01-19                 8,93%
# 2024-01-26                -0,52%
# 2024-02-02                 1,60%
# 2024-02-09                 4,71%
# 2024-02-16                -3,00%
#
# [1258 rows x 1 columns]
#             Mkt-RF   SMB   HML       RF  Variacion Logaritmica
# Date
# 2000-01-14    2.07  1.96 -1.50  0.00103                 0.0000
# 2000-01-21    0.02  6.94 -2.81  0.00103                 0.0000
# 2000-01-28   -5.71  0.17  1.75  0.00103                 0.0000
# 2000-02-04    4.46  1.26 -2.94  0.00108                 0.0000
# 2000-02-11   -1.45  6.24 -2.83  0.00108                 0.0000
# ...            ...   ...   ...      ...                    ...
# 2024-01-19    0.96 -1.40 -0.55  0.00118                 0.0893
# 2024-01-26    1.03  0.77  0.38  0.00118                -0.0052
# 2024-02-02    1.18 -1.96 -1.91  0.00106                 0.0160
# 2024-02-09    1.49  1.71 -2.17  0.00106                 0.0471
# 2024-02-16   -0.30  0.50  1.10  0.00106                -0.0300
#
# [1258 rows x 5 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.195
# Model:                            OLS   Adj. R-squared:                  0.193
# Method:                 Least Squares   F-statistic:                     101.2
# Date:                Sun, 28 Apr 2024   Prob (F-statistic):           1.16e-58
# Time:                        16:45:59   Log-Likelihood:                 2555.0
# No. Observations:                1258   AIC:                            -5102.
# Df Residuals:                    1254   BIC:                            -5081.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0023      0.001      2.610      0.009       0.001       0.004
# Mkt-RF         0.0059      0.000     16.438      0.000       0.005       0.007
# SMB            0.0008      0.001      1.133      0.258      -0.001       0.002
# HML           -0.0015      0.001     -2.983      0.003      -0.003      -0.001
# ==============================================================================
# Omnibus:                      143.572   Durbin-Watson:                   2.100
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1121.151
# Skew:                           0.182   Prob(JB):                    3.51e-244
# Kurtosis:                       7.611   Cond. No.                         2.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Procesando JPM...
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#            Variacion Logaritmica
# Date
# 2000-01-14                 1,53%
# 2000-01-21                -1,28%
# 2000-01-28                 5,01%
# 2000-02-04                 6,39%
# 2000-02-11                 1,06%
# ...                          ...
# 2024-01-19                 0,74%
# 2024-01-26                 1,15%
# 2024-02-02                 1,41%
# 2024-02-09                 0,16%
# 2024-02-16                 2,27%
#
# [1258 rows x 1 columns]
#             Mkt-RF   SMB   HML       RF  Variacion Logaritmica
# Date
# 2000-01-14    2.07  1.96 -1.50  0.00103                 0.0153
# 2000-01-21    0.02  6.94 -2.81  0.00103                -0.0128
# 2000-01-28   -5.71  0.17  1.75  0.00103                 0.0501
# 2000-02-04    4.46  1.26 -2.94  0.00108                 0.0639
# 2000-02-11   -1.45  6.24 -2.83  0.00108                 0.0106
# ...            ...   ...   ...      ...                    ...
# 2024-01-19    0.96 -1.40 -0.55  0.00118                 0.0074
# 2024-01-26    1.03  0.77  0.38  0.00118                 0.0115
# 2024-02-02    1.18 -1.96 -1.91  0.00106                 0.0141
# 2024-02-09    1.49  1.71 -2.17  0.00106                 0.0016
# 2024-02-16   -0.30  0.50  1.10  0.00106                 0.0227
#
# [1258 rows x 5 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.619
# Model:                            OLS   Adj. R-squared:                  0.618
# Method:                 Least Squares   F-statistic:                     679.1
# Date:                Sun, 28 Apr 2024   Prob (F-statistic):          3.86e-262
# Time:                        16:45:59   Log-Likelihood:                 2606.6
# No. Observations:                1258   AIC:                            -5205.
# Df Residuals:                    1254   BIC:                            -5185.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0015      0.001     -1.766      0.078      -0.003       0.000
# Mkt-RF         0.0133      0.000     38.309      0.000       0.013       0.014
# SMB           -0.0025      0.001     -3.936      0.000      -0.004      -0.001
# HML            0.0098      0.000     19.873      0.000       0.009       0.011
# ==============================================================================
# Omnibus:                      216.920   Durbin-Watson:                   2.163
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4184.121
# Skew:                           0.051   Prob(JB):                         0.00
# Kurtosis:                      11.934   Cond. No.                         2.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Procesando TSLA...
#            Variacion Logaritmica
# Date
# 2000-01-14                 0,00%
# 2000-01-21                 0,00%
# 2000-01-28                 0,00%
# 2000-02-04                 0,00%
# 2000-02-11                 0,00%
# ...                          ...
# 2024-01-19                -3,11%
# 2024-01-26               -14,66%
# 2024-02-02                 2,51%
# 2024-02-09                 2,97%
# 2024-02-16                 3,24%
#
# [1258 rows x 1 columns]
#             Mkt-RF   SMB   HML       RF  Variacion Logaritmica
# Date
# 2000-01-14    2.07  1.96 -1.50  0.00103                 0.0000
# 2000-01-21    0.02  6.94 -2.81  0.00103                 0.0000
# 2000-01-28   -5.71  0.17  1.75  0.00103                 0.0000
# 2000-02-04    4.46  1.26 -2.94  0.00108                 0.0000
# 2000-02-11   -1.45  6.24 -2.83  0.00108                 0.0000
# ...            ...   ...   ...      ...                    ...
# 2024-01-19    0.96 -1.40 -0.55  0.00118                -0.0311
# 2024-01-26    1.03  0.77  0.38  0.00118                -0.1466
# 2024-02-02    1.18 -1.96 -1.91  0.00106                 0.0251
# 2024-02-09    1.49  1.71 -2.17  0.00106                 0.0297
# 2024-02-16   -0.30  0.50  1.10  0.00106                 0.0324
#
# [1258 rows x 5 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.133
# Model:                            OLS   Adj. R-squared:                  0.131
# Method:                 Least Squares   F-statistic:                     64.21
# Date:                Sun, 28 Apr 2024   Prob (F-statistic):           1.27e-38
# Time:                        16:45:59   Log-Likelihood:                 1900.6
# No. Observations:                1258   AIC:                            -3793.
# Df Residuals:                    1254   BIC:                            -3773.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0026      0.002      1.743      0.082      -0.000       0.006
# Mkt-RF         0.0073      0.001     12.003      0.000       0.006       0.008
# SMB            0.0023      0.001      2.057      0.040       0.000       0.004
# HML           -0.0043      0.001     -5.009      0.000      -0.006      -0.003
# ==============================================================================
# Omnibus:                      166.290   Durbin-Watson:                   1.899
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1021.294
# Skew:                           0.432   Prob(JB):                    1.69e-222
# Kurtosis:                       7.329   Cond. No.                         2.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Procesando XOM...
# [*********************100%%**********************]  1 of 1 completed
#            Variacion Logaritmica
# Date
# 2000-01-14                -1,41%
# 2000-01-21                 1,48%
# 2000-01-28                -7,48%
# 2000-02-04                 2,50%
# 2000-02-11                -9,05%
# ...                          ...
# 2024-01-19                -3,05%
# 2024-01-26                 6,05%
# 2024-02-02                -1,01%
# 2024-02-09                -0,20%
# 2024-02-16                 1,91%
#
# [1258 rows x 1 columns]
#             Mkt-RF   SMB   HML       RF  Variacion Logaritmica
# Date
# 2000-01-14    2.07  1.96 -1.50  0.00103                -0.0141
# 2000-01-21    0.02  6.94 -2.81  0.00103                 0.0148
# 2000-01-28   -5.71  0.17  1.75  0.00103                -0.0748
# 2000-02-04    4.46  1.26 -2.94  0.00108                 0.0250
# 2000-02-11   -1.45  6.24 -2.83  0.00108                -0.0905
# ...            ...   ...   ...      ...                    ...
# 2024-01-19    0.96 -1.40 -0.55  0.00118                -0.0305
# 2024-01-26    1.03  0.77  0.38  0.00118                 0.0605
# 2024-02-02    1.18 -1.96 -1.91  0.00106                -0.0101
# 2024-02-09    1.49  1.71 -2.17  0.00106                -0.0020
# 2024-02-16   -0.30  0.50  1.10  0.00106                 0.0191
#
# [1258 rows x 5 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.410
# Model:                            OLS   Adj. R-squared:                  0.409
# Method:                 Least Squares   F-statistic:                     290.7
# Date:                Sun, 28 Apr 2024   Prob (F-statistic):          3.13e-143
# Time:                        16:45:59   Log-Likelihood:                 2807.8
# No. Observations:                1258   AIC:                            -5608.
# Df Residuals:                    1254   BIC:                            -5587.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0009      0.001     -1.183      0.237      -0.002       0.001
# Mkt-RF         0.0074      0.000     25.240      0.000       0.007       0.008
# SMB           -0.0014      0.001     -2.643      0.008      -0.003      -0.000
# HML            0.0053      0.000     12.699      0.000       0.005       0.006
# ==============================================================================
# Omnibus:                       82.282   Durbin-Watson:                   2.086
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              360.833
# Skew:                           0.021   Prob(JB):                     4.43e-79
# Kurtosis:                       5.623   Cond. No.                         2.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Procesando V...
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#            Variacion Logaritmica
# Date
# 2000-01-14                 0,00%
# 2000-01-21                 0,00%
# 2000-01-28                 0,00%
# 2000-02-04                 0,00%
# 2000-02-11                 0,00%
# ...                          ...
# 2024-01-19                 2,52%
# 2024-01-26                -1,10%
# 2024-02-02                 3,39%
# 2024-02-09                -0,27%
# 2024-02-16                 0,77%
#
# [1258 rows x 1 columns]
#             Mkt-RF   SMB   HML       RF  Variacion Logaritmica
# Date
# 2000-01-14    2.07  1.96 -1.50  0.00103                 0.0000
# 2000-01-21    0.02  6.94 -2.81  0.00103                 0.0000
# 2000-01-28   -5.71  0.17  1.75  0.00103                 0.0000
# 2000-02-04    4.46  1.26 -2.94  0.00108                 0.0000
# 2000-02-11   -1.45  6.24 -2.83  0.00108                 0.0000
# ...            ...   ...   ...      ...                    ...
# 2024-01-19    0.96 -1.40 -0.55  0.00118                 0.0252
# 2024-01-26    1.03  0.77  0.38  0.00118                -0.0110
# 2024-02-02    1.18 -1.96 -1.91  0.00106                 0.0339
# 2024-02-09    1.49  1.71 -2.17  0.00106                -0.0027
# 2024-02-16   -0.30  0.50  1.10  0.00106                 0.0077
#
# [1258 rows x 5 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.341
# Model:                            OLS   Adj. R-squared:                  0.339
# Method:                 Least Squares   F-statistic:                     215.9
# Date:                Sun, 28 Apr 2024   Prob (F-statistic):          6.43e-113
# Time:                        16:46:00   Log-Likelihood:                 2923.5
# No. Observations:                1258   AIC:                            -5839.
# Df Residuals:                    1254   BIC:                            -5818.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0011      0.001      1.604      0.109      -0.000       0.002
# Mkt-RF         0.0066      0.000     24.341      0.000       0.006       0.007
# SMB           -0.0003      0.000     -0.689      0.491      -0.001       0.001
# HML            0.0013      0.000      3.374      0.001       0.001       0.002
# ==============================================================================
# Omnibus:                      184.228   Durbin-Watson:                   2.138
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2514.170
# Skew:                           0.010   Prob(JB):                         0.00
# Kurtosis:                       9.926   Cond. No.                         2.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Procesando UNH...
#            Variacion Logaritmica
# Date
# 2000-01-14                 0,51%
# 2000-01-21                -5,42%
# 2000-01-28               -10,37%
# 2000-02-04                 7,55%
# 2000-02-11                -1,33%
# ...                          ...
# 2024-01-19                -3,50%
# 2024-01-26                -0,07%
# 2024-02-02                 1,39%
# 2024-02-09                 1,55%
# 2024-02-16                 0,64%
#
# [1258 rows x 1 columns]
#             Mkt-RF   SMB   HML       RF  Variacion Logaritmica
# Date
# 2000-01-14    2.07  1.96 -1.50  0.00103                 0.0051
# 2000-01-21    0.02  6.94 -2.81  0.00103                -0.0542
# 2000-01-28   -5.71  0.17  1.75  0.00103                -0.1037
# 2000-02-04    4.46  1.26 -2.94  0.00108                 0.0755
# 2000-02-11   -1.45  6.24 -2.83  0.00108                -0.0133
# ...            ...   ...   ...      ...                    ...
# 2024-01-19    0.96 -1.40 -0.55  0.00118                -0.0350
# 2024-01-26    1.03  0.77  0.38  0.00118                -0.0007
# 2024-02-02    1.18 -1.96 -1.91  0.00106                 0.0139
# 2024-02-09    1.49  1.71 -2.17  0.00106                 0.0155
# 2024-02-16   -0.30  0.50  1.10  0.00106                 0.0064
#
# [1258 rows x 5 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.286
# Model:                            OLS   Adj. R-squared:                  0.284
# Method:                 Least Squares   F-statistic:                     167.2
# Date:                Sun, 28 Apr 2024   Prob (F-statistic):           3.57e-91
# Time:                        16:46:00   Log-Likelihood:                 2385.2
# No. Observations:                1258   AIC:                            -4762.
# Df Residuals:                    1254   BIC:                            -4742.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0018      0.001      1.779      0.075      -0.000       0.004
# Mkt-RF         0.0088      0.000     21.390      0.000       0.008       0.010
# SMB           -0.0046      0.001     -6.067      0.000      -0.006      -0.003
# HML            0.0025      0.001      4.248      0.000       0.001       0.004
# ==============================================================================
# Omnibus:                      263.243   Durbin-Watson:                   2.098
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5158.235
# Skew:                          -0.414   Prob(JB):                         0.00
# Kurtosis:                      12.885   Cond. No.                         2.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Procesando MA...
# [*********************100%%**********************]  1 of 1 completed
#            Variacion Logaritmica
# Date
# 2000-01-14                 0,00%
# ...
# SMB            0.0006      0.001      1.006      0.315      -0.001       0.002
# HML           -0.0023      0.000     -4.658      0.000      -0.003      -0.001
# ==============================================================================
# Omnibus:                      325.841   Durbin-Watson:                   2.088
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5152.325
# Skew:                           0.757   Prob(JB):                         0.00
# Kurtosis:                      12.798   Cond. No.                         2.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Procesando ADBE...
# [*********************100%%**********************]  1 of 1 completed
#            Variacion Logaritmica
# Date
# 2000-01-14                 2,38%
# 2000-01-21                -5,32%
# 2000-01-28                -8,83%
# 2000-02-04                25,12%
# 2000-02-11                20,06%
# ...                          ...
# 2024-01-19                 2,49%
# 2024-01-26                 0,39%
# 2024-02-02                 3,34%
# 2024-02-09                -1,20%
# 2024-02-16               -13,75%
#
# [1258 rows x 1 columns]
#             Mkt-RF   SMB   HML       RF  Variacion Logaritmica
# Date
# 2000-01-14    2.07  1.96 -1.50  0.00103                 0.0238
# 2000-01-21    0.02  6.94 -2.81  0.00103                -0.0532
# 2000-01-28   -5.71  0.17  1.75  0.00103                -0.0883
# 2000-02-04    4.46  1.26 -2.94  0.00108                 0.2512
# 2000-02-11   -1.45  6.24 -2.83  0.00108                 0.2006
# ...            ...   ...   ...      ...                    ...
# 2024-01-19    0.96 -1.40 -0.55  0.00118                 0.0249
# 2024-01-26    1.03  0.77  0.38  0.00118                 0.0039
# 2024-02-02    1.18 -1.96 -1.91  0.00106                 0.0334
# 2024-02-09    1.49  1.71 -2.17  0.00106                -0.0120
# 2024-02-16   -0.30  0.50  1.10  0.00106                -0.1375
#
# [1258 rows x 5 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.394
# Model:                            OLS   Adj. R-squared:                  0.393
# Method:                 Least Squares   F-statistic:                     271.9
# Date:                Sun, 28 Apr 2024   Prob (F-statistic):          6.56e-136
# Time:                        16:46:05   Log-Likelihood:                 2227.6
# No. Observations:                1258   AIC:                            -4447.
# Df Residuals:                    1254   BIC:                            -4427.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0011      0.001      0.960      0.337      -0.001       0.003
# Mkt-RF         0.0124      0.000     26.460      0.000       0.011       0.013
# SMB           -0.0007      0.001     -0.766      0.444      -0.002       0.001
# HML           -0.0070      0.001    -10.546      0.000      -0.008      -0.006
# ==============================================================================
# Omnibus:                      328.033   Durbin-Watson:                   1.842
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4919.410
# Skew:                          -0.782   Prob(JB):                         0.00
# Kurtosis:                      12.561   Cond. No.                         2.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Procesando DIS...
# [*********************100%%**********************]  1 of 1 completed
#            Variacion Logaritmica
# Date
# 2000-01-14                 7,54%
# 2000-01-21                -2,45%
# 2000-01-28                11,52%
# 2000-02-04                 3,67%
# 2000-02-11                -0,66%
# ...                          ...
# 2024-01-19                 2,96%
# 2024-01-26                 2,44%
# 2024-02-02                 1,84%
# 2024-02-09                10,97%
# 2024-02-16                 2,92%
#
# [1258 rows x 1 columns]
#             Mkt-RF   SMB   HML       RF  Variacion Logaritmica
# Date
# 2000-01-14    2.07  1.96 -1.50  0.00103                 0.0754
# 2000-01-21    0.02  6.94 -2.81  0.00103                -0.0245
# 2000-01-28   -5.71  0.17  1.75  0.00103                 0.1152
# 2000-02-04    4.46  1.26 -2.94  0.00108                 0.0367
# 2000-02-11   -1.45  6.24 -2.83  0.00108                -0.0066
# ...            ...   ...   ...      ...                    ...
# 2024-01-19    0.96 -1.40 -0.55  0.00118                 0.0296
# 2024-01-26    1.03  0.77  0.38  0.00118                 0.0244
# 2024-02-02    1.18 -1.96 -1.91  0.00106                 0.0184
# 2024-02-09    1.49  1.71 -2.17  0.00106                 0.1097
# 2024-02-16   -0.30  0.50  1.10  0.00106                 0.0292
#
# [1258 rows x 5 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.479
# Model:                            OLS   Adj. R-squared:                  0.478
# Method:                 Least Squares   F-statistic:                     384.6
# Date:                Sun, 28 Apr 2024   Prob (F-statistic):          4.31e-177
# Time:                        16:46:06   Log-Likelihood:                 2695.0
# No. Observations:                1258   AIC:                            -5382.
# Df Residuals:                    1254   BIC:                            -5361.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0008      0.001     -1.016      0.310      -0.002       0.001
# Mkt-RF         0.0106      0.000     32.816      0.000       0.010       0.011
# SMB           -0.0012      0.001     -1.953      0.051      -0.002    5.09e-06
# HML            0.0017      0.000      3.691      0.000       0.001       0.003
# ==============================================================================
# Omnibus:                      147.885   Durbin-Watson:                   2.060
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1249.668
# Skew:                           0.156   Prob(JB):                    4.34e-272
# Kurtosis:                       7.873   Cond. No.                         2.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Procesando ACN...
# [*********************100%%**********************]  1 of 1 completed
#            Variacion Logaritmica
# Date
# 2000-01-14                 0,00%
# 2000-01-21                 0,00%
# 2000-01-28                 0,00%
# 2000-02-04                 0,00%
# 2000-02-11                 0,00%
# ...                          ...
# 2024-01-19                 2,10%
# 2024-01-26                 1,95%
# 2024-02-02                 0,51%
# 2024-02-09                -0,34%
# 2024-02-16                -0,59%
#
# [1258 rows x 1 columns]
#             Mkt-RF   SMB   HML       RF  Variacion Logaritmica
# Date
# 2000-01-14    2.07  1.96 -1.50  0.00103                 0.0000
# 2000-01-21    0.02  6.94 -2.81  0.00103                 0.0000
# 2000-01-28   -5.71  0.17  1.75  0.00103                 0.0000
# 2000-02-04    4.46  1.26 -2.94  0.00108                 0.0000
# 2000-02-11   -1.45  6.24 -2.83  0.00108                 0.0000
# ...            ...   ...   ...      ...                    ...
# 2024-01-19    0.96 -1.40 -0.55  0.00118                 0.0210
# 2024-01-26    1.03  0.77  0.38  0.00118                 0.0195
# 2024-02-02    1.18 -1.96 -1.91  0.00106                 0.0051
# 2024-02-09    1.49  1.71 -2.17  0.00106                -0.0034
# 2024-02-16   -0.30  0.50  1.10  0.00106                -0.0059
#
# [1258 rows x 5 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.371
# Model:                            OLS   Adj. R-squared:                  0.369
# Method:                 Least Squares   F-statistic:                     246.3
# Date:                Sun, 28 Apr 2024   Prob (F-statistic):          1.29e-125
# Time:                        16:46:06   Log-Likelihood:                 2627.8
# No. Observations:                1258   AIC:                            -5248.
# Df Residuals:                    1254   BIC:                            -5227.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0010      0.001      1.187      0.235      -0.001       0.003
# Mkt-RF         0.0090      0.000     26.436      0.000       0.008       0.010
# SMB           -0.0002      0.001     -0.388      0.698      -0.001       0.001
# HML           -0.0008      0.000     -1.623      0.105      -0.002       0.000
# ==============================================================================
# Omnibus:                      134.815   Durbin-Watson:                   2.253
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1053.991
# Skew:                           0.076   Prob(JB):                    1.35e-229
# Kurtosis:                       7.482   Cond. No.                         2.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Procesando WFC...
# [*********************100%%**********************]  1 of 1 completed
#            Variacion Logaritmica
# Date
# 2000-01-14                 6,34%
# 2000-01-21               -12,95%
# 2000-01-28                 5,64%
# 2000-02-04                -0,49%
# 2000-02-11                -1,80%
# ...                          ...
# 2024-01-19                 1,51%
# 2024-01-26                 4,47%
# 2024-02-02                -2,33%
# 2024-02-09                -2,26%
# 2024-02-16                 7,71%
#
# [1258 rows x 1 columns]
#             Mkt-RF   SMB   HML       RF  Variacion Logaritmica
# Date
# 2000-01-14    2.07  1.96 -1.50  0.00103                 0.0634
# 2000-01-21    0.02  6.94 -2.81  0.00103                -0.1295
# 2000-01-28   -5.71  0.17  1.75  0.00103                 0.0564
# 2000-02-04    4.46  1.26 -2.94  0.00108                -0.0049
# 2000-02-11   -1.45  6.24 -2.83  0.00108                -0.0180
# ...            ...   ...   ...      ...                    ...
# 2024-01-19    0.96 -1.40 -0.55  0.00118                 0.0151
# 2024-01-26    1.03  0.77  0.38  0.00118                 0.0447
# 2024-02-02    1.18 -1.96 -1.91  0.00106                -0.0233
# 2024-02-09    1.49  1.71 -2.17  0.00106                -0.0226
# 2024-02-16   -0.30  0.50  1.10  0.00106                 0.0771
#
# [1258 rows x 5 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.616
# Model:                            OLS   Adj. R-squared:                  0.615
# Method:                 Least Squares   F-statistic:                     669.5
# Date:                Sun, 28 Apr 2024   Prob (F-statistic):          9.84e-260
# Time:                        16:46:06   Log-Likelihood:                 2584.2
# No. Observations:                1258   AIC:                            -5160.
# Df Residuals:                    1254   BIC:                            -5140.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0017      0.001     -1.966      0.050      -0.003   -3.67e-06
# Mkt-RF         0.0117      0.000     33.243      0.000       0.011       0.012
# SMB           -0.0032      0.001     -4.878      0.000      -0.004      -0.002
# HML            0.0134      0.001     26.603      0.000       0.012       0.014
# ==============================================================================
# Omnibus:                      229.975   Durbin-Watson:                   2.271
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3885.714
# Skew:                           0.303   Prob(JB):                         0.00
# Kurtosis:                      11.589   Cond. No.                         2.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Procesando ORCL...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-119-7e23696e9942> in <cell line: 9>()
#      11     try:
#      12         # Ejecuta tu función de regresión para el ticker actual
# ---> 13         resultado = regresion(ticker)
#      14
#      15         # Almacena el resultado en el diccionario
#
# <ipython-input-117-c00f960d5a9f> in regresion(ticker)
#      11
#      12
# ---> 13   df_variacion_log = obtener_precios_logaritmicos(ticker,fechas)
#      14   df_variacion_log.head()
#      15
#
# <ipython-input-111-ff3939cec929> in obtener_precios_logaritmicos(ticker, fechas)
#      45     """
#      46     # Descargar datos de un rango que cubra las fechas dadas
# ---> 47     datos = yf.download(ticker, start=min(fechas), end=max(fechas))
#      48
#      49     # Asegurarse que las fechas son tratadas como datetime
#
# /usr/local/lib/python3.10/dist-packages/yfinance/utils.py in wrapper(*args, **kwargs)
#     101
#     102         with IndentationContext():
# --> 103             result = func(*args, **kwargs)
#     104
#     105         logger.debug(f'Exiting {func.__name__}()')
#
# /usr/local/lib/python3.10/dist-packages/yfinance/multi.py in download(tickers, start, end, actions, threads, ignore_tz, group_by, auto_adjust, back_adjust, repair, keepna, progress, period, show_errors, interval, prepost, proxy, rounding, timeout, session)
#     161                                    rounding=rounding, timeout=timeout)
#     162         while len(shared._DFS) < len(tickers):
# --> 163             _time.sleep(0.01)
#     164     # download synchronously
#     165     else:
#
# KeyboardInterrupt:

# %%
from datetime import datetimedf_combinado.to_csv('ex.csv', sep = ";", index=True)
