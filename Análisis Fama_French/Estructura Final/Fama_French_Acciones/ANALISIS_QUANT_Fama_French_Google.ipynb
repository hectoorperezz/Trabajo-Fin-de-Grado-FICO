# %% [markdown]
# ## **Análisis Cuantitativo del Impacto de los Flujos de Capital hacia ETFs en la Valoración del S&P500**

# %% [markdown]
# Este estudio tiene como objetivo realizar una contribución significativa a la investigación financiera existente. Mediante la expansión del modelo Fama-French, busca explorar la influencia de los flujos de fondos —específicamente, el capital que entra y sale de los fondos de inversión que tienen participaciones en Apple— en los rendimientos de las acciones de la empresa.
#
# El modelo ampliado se formula de la siguiente manera:
#
#
# R_{apple,t} - R_{f,t} = \alpha + \beta_m(R_{m,t} - R_{f,t}) + \beta_sSMB_t + \beta_hHML_t + \beta_fFF_t + \epsilon_t
#
# Donde:
# - `R_{apple,t} - R_{f,t}` es el exceso de rendimiento de las acciones de Apple sobre la tasa libre de riesgo en el tiempo t.
# - `\alpha` es el término de intercepción del modelo.
# - `\beta_m, \beta_s, \beta_h, \beta_f` son los coeficientes de sensibilidad a los factores de mercado, tamaño, valor, y flujos de fondos, respectivamente.
# - `R_{m,t} - R_{f,t}` representa el exceso de rendimiento del mercado.
# - `SMB_t` y `HML_t` son los factores de tamaño y valor del modelo Fama-French.
# - `FF_t` es el factor adicional de flujos de fondos propuesto.
# - `\epsilon_t` es el término de error.
#
#
#
# Este enfoque permite evaluar si los flujos monetarios hacia o desde fondos de inversión ejercen una influencia significativa en la valoración de Apple, aportando una nueva dimensión al análisis tradicional de rendimientos de acciones.

# %%
import pandas as pd
import statsmodels.api as sm

# Cargar el CSV en un DataFrame
df = pd.read_csv('/content/drive/MyDrive/TFG/CSVs/csv_final/csv_googl.csv', sep = ';')

print(df)
# Out:
#           Date Mkt-RF    SMB    HML     RF rendimientos google % Fundflows
# 0       4/1/18   0,42  -0,26   0,24  0,60%               0,38%      -0,36%
# 1       5/1/18   0,66  -0,35  -0,26  0,60%               1,31%      -0,19%
# 2       8/1/18   0,19  -0,15   0,05  0,60%               0,36%      -0,46%
# 3       9/1/18   0,15  -0,35  -0,04  0,60%              -0,13%       0,82%
# 4      10/1/18  -0,07   0,07   0,57  0,60%              -0,23%       0,43%
# ...        ...    ...    ...    ...    ...                 ...         ...
# 1508  21/12/23   0,34  -0,43  -0,88  2,10%               1,49%       0,25%
# 1509  22/12/23   1,55   1,72   1,35  2,10%               0,76%       0,28%
# 1510  26/12/23   0,51   1,12   2,05  2,10%               0,02%       0,49%
# 1511  27/12/23  -0,06   -0,4  -0,57  2,10%              -0,82%       0,51%
# 1512  28/12/23   0,42  -0,38  -0,38  2,10%              -0,10%       0,20%
#
# [1513 rows x 7 columns]

# %%
import pandas as pd


# Spanish month abbreviations to English
spanish_months = {
    'ene': 'Jan', 'feb': 'Feb', 'mar': 'Mar', 'abr': 'Apr', 'may': 'May', 'jun': 'Jun',
    'jul': 'Jul', 'ago': 'Aug', 'sep': 'Sep', 'oct': 'Oct', 'nov': 'Nov', 'dic': 'Dec'
}

# Replace the Spanish month abbreviations with English abbreviations
df['Date'] = df['Date'].replace(spanish_months, regex=True)

print(df)
# Out:
#           Date Mkt-RF    SMB    HML     RF rendimientos google % Fundflows
# 0       4/1/18   0,42  -0,26   0,24  0,60%               0,38%      -0,36%
# 1       5/1/18   0,66  -0,35  -0,26  0,60%               1,31%      -0,19%
# 2       8/1/18   0,19  -0,15   0,05  0,60%               0,36%      -0,46%
# 3       9/1/18   0,15  -0,35  -0,04  0,60%              -0,13%       0,82%
# 4      10/1/18  -0,07   0,07   0,57  0,60%              -0,23%       0,43%
# ...        ...    ...    ...    ...    ...                 ...         ...
# 1508  21/12/23   0,34  -0,43  -0,88  2,10%               1,49%       0,25%
# 1509  22/12/23   1,55   1,72   1,35  2,10%               0,76%       0,28%
# 1510  26/12/23   0,51   1,12   2,05  2,10%               0,02%       0,49%
# 1511  27/12/23  -0,06   -0,4  -0,57  2,10%              -0,82%       0,51%
# 1512  28/12/23   0,42  -0,38  -0,38  2,10%              -0,10%       0,20%
#
# [1513 rows x 7 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])
print(df.columns)
print(df)
print(df.dtypes)
format='%b-%Y'
# Out:
# Index(['Date', 'Mkt-RF', 'SMB', 'HML', 'RF', 'rendimientos google',
#        '% Fundflows'],
#       dtype='object')
#            Date Mkt-RF    SMB    HML     RF rendimientos google % Fundflows
# 0    2018-04-01   0,42  -0,26   0,24  0,60%               0,38%      -0,36%
# 1    2018-05-01   0,66  -0,35  -0,26  0,60%               1,31%      -0,19%
# 2    2018-08-01   0,19  -0,15   0,05  0,60%               0,36%      -0,46%
# 3    2018-09-01   0,15  -0,35  -0,04  0,60%              -0,13%       0,82%
# 4    2018-10-01  -0,07   0,07   0,57  0,60%              -0,23%       0,43%
# ...         ...    ...    ...    ...    ...                 ...         ...
# 1508 2023-12-21   0,34  -0,43  -0,88  2,10%               1,49%       0,25%
# 1509 2023-12-22   1,55   1,72   1,35  2,10%               0,76%       0,28%
# 1510 2023-12-26   0,51   1,12   2,05  2,10%               0,02%       0,49%
# 1511 2023-12-27  -0,06   -0,4  -0,57  2,10%              -0,82%       0,51%
# 1512 2023-12-28   0,42  -0,38  -0,38  2,10%              -0,10%       0,20%
#
# [1513 rows x 7 columns]
# Date                   datetime64[ns]
# Mkt-RF                         object
# SMB                            object
# HML                            object
# RF                             object
# rendimientos google            object
# % Fundflows                    object
# dtype: object

# %%
# Eliminar la última fila utilizando .drop() y iloc
df.drop(df.iloc[-1].name, inplace=True)



# Verifica tu DataFrame
print(df)

# Verifica los cambios
print(df.head())
print(df.dtypes)
# Out:
#            Date Mkt-RF    SMB    HML     RF rendimientos google % Fundflows
# 0    2018-04-01   0,42  -0,26   0,24  0,60%               0,38%      -0,36%
# 1    2018-05-01   0,66  -0,35  -0,26  0,60%               1,31%      -0,19%
# 2    2018-08-01   0,19  -0,15   0,05  0,60%               0,36%      -0,46%
# 3    2018-09-01   0,15  -0,35  -0,04  0,60%              -0,13%       0,82%
# 4    2018-10-01  -0,07   0,07   0,57  0,60%              -0,23%       0,43%
# ...         ...    ...    ...    ...    ...                 ...         ...
# 1507 2023-12-20   0,34  -0,39  -0,12  2,10%               1,23%       0,76%
# 1508 2023-12-21   0,34  -0,43  -0,88  2,10%               1,49%       0,25%
# 1509 2023-12-22   1,55   1,72   1,35  2,10%               0,76%       0,28%
# 1510 2023-12-26   0,51   1,12   2,05  2,10%               0,02%       0,49%
# 1511 2023-12-27  -0,06   -0,4  -0,57  2,10%              -0,82%       0,51%
#
# [1512 rows x 7 columns]
#         Date Mkt-RF    SMB    HML     RF rendimientos google % Fundflows
# 0 2018-04-01   0,42  -0,26   0,24  0,60%               0,38%      -0,36%
# 1 2018-05-01   0,66  -0,35  -0,26  0,60%               1,31%      -0,19%
# 2 2018-08-01   0,19  -0,15   0,05  0,60%               0,36%      -0,46%
# 3 2018-09-01   0,15  -0,35  -0,04  0,60%              -0,13%       0,82%
# 4 2018-10-01  -0,07   0,07   0,57  0,60%              -0,23%       0,43%
# Date                   datetime64[ns]
# Mkt-RF                         object
# SMB                            object
# HML                            object
# RF                             object
# rendimientos google            object
# % Fundflows                    object
# dtype: object

# %%
# Reemplaza las comas en los números y convierte las columnas a float
df['Mkt-RF'] = df['Mkt-RF'].str.replace(',', '.').astype(float)
df['SMB'] = df['SMB'].str.replace(',', '.').astype(float)
df['HML'] = df['HML'].str.replace(',', '.').astype(float)

# Convierte las columnas de RF y rendimientos de apple de porcentaje a float
df['RF'] = df['RF'].str.rstrip('%').str.replace(',', '.').astype(float) / 100
df['rendimientos google'] = df['rendimientos google'].str.rstrip('%').str.replace(',', '.').astype(float) / 100

# Para % Fundflows, maneja los NaNs antes de la conversión si es necesario
df['% Fundflows'] = df['% Fundflows'].str.rstrip('%').str.replace(',', '.').astype(float) / 100

# Verifica los cambios
print(df.head())
print(df.dtypes)
# Out:
#         Date  Mkt-RF   SMB   HML     RF  rendimientos google  % Fundflows
# 0 2018-04-01    0.42 -0.26  0.24  0.006               0.0038      -0.0036
# 1 2018-05-01    0.66 -0.35 -0.26  0.006               0.0131      -0.0019
# 2 2018-08-01    0.19 -0.15  0.05  0.006               0.0036      -0.0046
# 3 2018-09-01    0.15 -0.35 -0.04  0.006              -0.0013       0.0082
# 4 2018-10-01   -0.07  0.07  0.57  0.006              -0.0023       0.0043
# Date                   datetime64[ns]
# Mkt-RF                        float64
# SMB                           float64
# HML                           float64
# RF                            float64
# rendimientos google           float64
# % Fundflows                   float64
# dtype: object

# %%
import statsmodels.api as sm

# Preparar las variables independientes
# Añadir una constante al modelo para el término de intercepción
X = df[['Mkt-RF', 'SMB', 'HML', '% Fundflows']]
X = sm.add_constant(X)

# La variable dependiente es el exceso de rendimiento de Apple
# Asegúrate de que 'RF' y 'rendimientos apple' están en formato decimal adecuado
Y = df['rendimientos google'] - df['RF']

# Estimar el modelo OLS
modelo = sm.OLS(Y, X).fit()

# Mostrar el resumen del modelo
print(modelo.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.198
# Model:                            OLS   Adj. R-squared:                  0.196
# Method:                 Least Squares   F-statistic:                     93.02
# Date:                Wed, 27 Mar 2024   Prob (F-statistic):           9.22e-71
# Time:                        19:40:50   Log-Likelihood:                 3878.3
# No. Observations:                1512   AIC:                            -7747.
# Df Residuals:                    1507   BIC:                            -7720.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -0.0066      0.000    -13.723      0.000      -0.008      -0.006
# Mkt-RF          0.0070      0.000     19.106      0.000       0.006       0.008
# SMB            -0.0033      0.001     -4.784      0.000      -0.005      -0.002
# HML            -0.0005      0.000     -1.103      0.270      -0.001       0.000
# % Fundflows     0.0170      0.076      0.222      0.824      -0.133       0.167
# ==============================================================================
# Omnibus:                      163.954   Durbin-Watson:                   1.739
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1020.159
# Skew:                          -0.284   Prob(JB):                    2.99e-222
# Kurtosis:                       6.984   Cond. No.                         215.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import pandas as pd
import statsmodels.api as sm

# Step 1: Convert the 'date' column to datetime if it's not already
df['Date'] = pd.to_datetime(df['Date'])

# Step 2: Filter the DataFrame for the desired date range
start_date = '2020-01-01'
end_date = '2023-12-31'
mask = (df['Date'] >= start_date) & (df['Date'] <= end_date)
filtered_df = df.loc[mask]

# Step 3: Prepare the independent variables, add a constant for the intercept
X = filtered_df[['Mkt-RF', 'SMB', 'HML', '% Fundflows']]
X = sm.add_constant(X)

# Ensure 'RF' and 'rendimientos tesla' are in the correct decimal format
Y = filtered_df['rendimientos google'] - filtered_df['RF']

# Estimate the OLS model
modelo = sm.OLS(Y, X).fit()

# Show the model summary
print(modelo.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.139
# Model:                            OLS   Adj. R-squared:                  0.136
# Method:                 Least Squares   F-statistic:                     40.57
# Date:                Wed, 27 Mar 2024   Prob (F-statistic):           1.54e-31
# Time:                        19:41:04   Log-Likelihood:                 2470.0
# No. Observations:                1010   AIC:                            -4930.
# Df Residuals:                    1005   BIC:                            -4905.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -0.0059      0.001     -8.912      0.000      -0.007      -0.005
# Mkt-RF          0.0058      0.000     12.659      0.000       0.005       0.007
# SMB            -0.0035      0.001     -4.091      0.000      -0.005      -0.002
# HML             0.0002      0.001      0.420      0.674      -0.001       0.001
# % Fundflows    -0.0444      0.111     -0.400      0.689      -0.262       0.173
# ==============================================================================
# Omnibus:                       78.342   Durbin-Watson:                   1.735
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              272.425
# Skew:                          -0.308   Prob(JB):                     6.98e-60
# Kurtosis:                       5.469   Cond. No.                         252.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
