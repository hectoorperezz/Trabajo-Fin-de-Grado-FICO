# %% [markdown]
# ## **Análisis Cuantitativo del Impacto de los Flujos de Capital hacia ETFs en la Valoración del S&P500**

# %% [markdown]
# Este estudio tiene como objetivo realizar una contribución significativa a la investigación financiera existente. Mediante la expansión del modelo Fama-French, busca explorar la influencia de los flujos de fondos —específicamente, el capital que entra y sale de los fondos de inversión que tienen participaciones en Apple— en los rendimientos de las acciones de la empresa.
#
# El modelo ampliado se formula de la siguiente manera:
#
#
# R_{apple,t} - R_{f,t} = \alpha + \beta_m(R_{m,t} - R_{f,t}) + \beta_sSMB_t + \beta_hHML_t + \beta_fFF_t + \epsilon_t
#
# Donde:
# - `R_{apple,t} - R_{f,t}` es el exceso de rendimiento de las acciones de Apple sobre la tasa libre de riesgo en el tiempo t.
# - `\alpha` es el término de intercepción del modelo.
# - `\beta_m, \beta_s, \beta_h, \beta_f` son los coeficientes de sensibilidad a los factores de mercado, tamaño, valor, y flujos de fondos, respectivamente.
# - `R_{m,t} - R_{f,t}` representa el exceso de rendimiento del mercado.
# - `SMB_t` y `HML_t` son los factores de tamaño y valor del modelo Fama-French.
# - `FF_t` es el factor adicional de flujos de fondos propuesto.
# - `\epsilon_t` es el término de error.
#
#
#
# Este enfoque permite evaluar si los flujos monetarios hacia o desde fondos de inversión ejercen una influencia significativa en la valoración de Apple, aportando una nueva dimensión al análisis tradicional de rendimientos de acciones.

# %%
import pandas as pd
import statsmodels.api as sm

# Cargar el CSV en un DataFrame
df = pd.read_csv('/content/Book2.csv', sep = ';')

print(df)
# Out:
#           Date Mkt-RF    SMB    HML     RF rendimientos nvidia % Fundflows  \
# 0       3/1/18   0,59  -0,39  -0,18  0,60%               6,37%      -0,08%
# 1       4/1/18   0,42  -0,26   0,24  0,60%               0,53%      -0,36%
# 2       5/1/18   0,66  -0,35  -0,26  0,60%               0,84%      -0,19%
# 3       8/1/18   0,19  -0,15   0,05  0,60%               3,02%      -0,46%
# 4       9/1/18   0,15  -0,35  -0,04  0,60%              -0,04%       0,82%
# ...        ...    ...    ...    ...    ...                 ...         ...
# 1510  22/12/23   1,55   1,72   1,35  2,10%              -0,33%       0,28%
# 1511  26/12/23   0,51   1,12   2,05  2,10%               0,92%       0,49%
# 1512  27/12/23  -0,06   -0,4  -0,57  2,10%               0,28%       0,51%
# 1513  28/12/23   0,42  -0,38  -0,38  2,10%               0,21%       0,20%
# 1514  29/12/23   0,72   1,35    0,7  2,10%               0,00%       0,31%
#
#       Unnamed: 7  Unnamed: 8  Unnamed: 9
# 0            NaN         NaN         NaN
# 1            NaN         NaN         NaN
# 2            NaN         NaN         NaN
# 3            NaN         NaN         NaN
# 4            NaN         NaN         NaN
# ...          ...         ...         ...
# 1510         NaN         NaN         NaN
# 1511         NaN         NaN         NaN
# 1512         NaN         NaN         NaN
# 1513         NaN         NaN         NaN
# 1514         NaN         NaN         NaN
#
# [1515 rows x 10 columns]

# %%
import pandas as pd


# Spanish month abbreviations to English
spanish_months = {
    'ene': 'Jan', 'feb': 'Feb', 'mar': 'Mar', 'abr': 'Apr', 'may': 'May', 'jun': 'Jun',
    'jul': 'Jul', 'ago': 'Aug', 'sep': 'Sep', 'oct': 'Oct', 'nov': 'Nov', 'dic': 'Dec'
}

# Replace the Spanish month abbreviations with English abbreviations
df['Date'] = df['Date'].replace(spanish_months, regex=True)

print(df)
# Out:
#           Date Mkt-RF    SMB    HML     RF rendimientos nvidia % Fundflows  \
# 0       3/1/18   0,59  -0,39  -0,18  0,60%               6,37%      -0,08%
# 1       4/1/18   0,42  -0,26   0,24  0,60%               0,53%      -0,36%
# 2       5/1/18   0,66  -0,35  -0,26  0,60%               0,84%      -0,19%
# 3       8/1/18   0,19  -0,15   0,05  0,60%               3,02%      -0,46%
# 4       9/1/18   0,15  -0,35  -0,04  0,60%              -0,04%       0,82%
# ...        ...    ...    ...    ...    ...                 ...         ...
# 1510  22/12/23   1,55   1,72   1,35  2,10%              -0,33%       0,28%
# 1511  26/12/23   0,51   1,12   2,05  2,10%               0,92%       0,49%
# 1512  27/12/23  -0,06   -0,4  -0,57  2,10%               0,28%       0,51%
# 1513  28/12/23   0,42  -0,38  -0,38  2,10%               0,21%       0,20%
# 1514  29/12/23   0,72   1,35    0,7  2,10%               0,00%       0,31%
#
#       Unnamed: 7  Unnamed: 8  Unnamed: 9
# 0            NaN         NaN         NaN
# 1            NaN         NaN         NaN
# 2            NaN         NaN         NaN
# 3            NaN         NaN         NaN
# 4            NaN         NaN         NaN
# ...          ...         ...         ...
# 1510         NaN         NaN         NaN
# 1511         NaN         NaN         NaN
# 1512         NaN         NaN         NaN
# 1513         NaN         NaN         NaN
# 1514         NaN         NaN         NaN
#
# [1515 rows x 10 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])
print(df.columns)
print(df)
print(df.dtypes)
format='%b-%Y'
# Out:
# Index(['Date', 'Mkt-RF', 'SMB', 'HML', 'RF', 'rendimientos nvidia',
#        '% Fundflows', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')
#            Date Mkt-RF    SMB    HML     RF rendimientos nvidia % Fundflows  \
# 0    2018-03-01   0,59  -0,39  -0,18  0,60%               6,37%      -0,08%
# 1    2018-04-01   0,42  -0,26   0,24  0,60%               0,53%      -0,36%
# 2    2018-05-01   0,66  -0,35  -0,26  0,60%               0,84%      -0,19%
# 3    2018-08-01   0,19  -0,15   0,05  0,60%               3,02%      -0,46%
# 4    2018-09-01   0,15  -0,35  -0,04  0,60%              -0,04%       0,82%
# ...         ...    ...    ...    ...    ...                 ...         ...
# 1510 2023-12-22   1,55   1,72   1,35  2,10%              -0,33%       0,28%
# 1511 2023-12-26   0,51   1,12   2,05  2,10%               0,92%       0,49%
# 1512 2023-12-27  -0,06   -0,4  -0,57  2,10%               0,28%       0,51%
# 1513 2023-12-28   0,42  -0,38  -0,38  2,10%               0,21%       0,20%
# 1514 2023-12-29   0,72   1,35    0,7  2,10%               0,00%       0,31%
#
#       Unnamed: 7  Unnamed: 8  Unnamed: 9
# 0            NaN         NaN         NaN
# 1            NaN         NaN         NaN
# 2            NaN         NaN         NaN
# 3            NaN         NaN         NaN
# 4            NaN         NaN         NaN
# ...          ...         ...         ...
# 1510         NaN         NaN         NaN
# 1511         NaN         NaN         NaN
# 1512         NaN         NaN         NaN
# 1513         NaN         NaN         NaN
# 1514         NaN         NaN         NaN
#
# [1515 rows x 10 columns]
# Date                   datetime64[ns]
# Mkt-RF                         object
# SMB                            object
# HML                            object
# RF                             object
# rendimientos nvidia            object
# % Fundflows                    object
# Unnamed: 7                    float64
# Unnamed: 8                    float64
# Unnamed: 9                    float64
# dtype: object

# %%
# Eliminar la última fila utilizando .drop() y iloc
df.drop(df.iloc[-1].name, inplace=True)



# Verifica tu DataFrame
print(df)

# Verifica los cambios
print(df.head())
print(df.dtypes)
# Out:
#            Date Mkt-RF    SMB    HML     RF rendimientos nvidia % Fundflows  \
# 0    2018-03-01   0,59  -0,39  -0,18  0,60%               6,37%      -0,08%
# 1    2018-04-01   0,42  -0,26   0,24  0,60%               0,53%      -0,36%
# 2    2018-05-01   0,66  -0,35  -0,26  0,60%               0,84%      -0,19%
# 3    2018-08-01   0,19  -0,15   0,05  0,60%               3,02%      -0,46%
# 4    2018-09-01   0,15  -0,35  -0,04  0,60%              -0,04%       0,82%
# ...         ...    ...    ...    ...    ...                 ...         ...
# 1509 2023-12-21   0,34  -0,43  -0,88  2,10%               1,81%       0,25%
# 1510 2023-12-22   1,55   1,72   1,35  2,10%              -0,33%       0,28%
# 1511 2023-12-26   0,51   1,12   2,05  2,10%               0,92%       0,49%
# 1512 2023-12-27  -0,06   -0,4  -0,57  2,10%               0,28%       0,51%
# 1513 2023-12-28   0,42  -0,38  -0,38  2,10%               0,21%       0,20%
#
#       Unnamed: 7  Unnamed: 8  Unnamed: 9
# 0            NaN         NaN         NaN
# 1            NaN         NaN         NaN
# 2            NaN         NaN         NaN
# 3            NaN         NaN         NaN
# 4            NaN         NaN         NaN
# ...          ...         ...         ...
# 1509         NaN         NaN         NaN
# 1510         NaN         NaN         NaN
# 1511         NaN         NaN         NaN
# 1512         NaN         NaN         NaN
# 1513         NaN         NaN         NaN
#
# [1514 rows x 10 columns]
#         Date Mkt-RF    SMB    HML     RF rendimientos nvidia % Fundflows  \
# 0 2018-03-01   0,59  -0,39  -0,18  0,60%               6,37%      -0,08%
# 1 2018-04-01   0,42  -0,26   0,24  0,60%               0,53%      -0,36%
# 2 2018-05-01   0,66  -0,35  -0,26  0,60%               0,84%      -0,19%
# 3 2018-08-01   0,19  -0,15   0,05  0,60%               3,02%      -0,46%
# 4 2018-09-01   0,15  -0,35  -0,04  0,60%              -0,04%       0,82%
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN
# Date                   datetime64[ns]
# Mkt-RF                         object
# SMB                            object
# HML                            object
# RF                             object
# rendimientos nvidia            object
# % Fundflows                    object
# Unnamed: 7                    float64
# Unnamed: 8                    float64
# Unnamed: 9                    float64
# dtype: object

# %%
# Reemplaza las comas en los números y convierte las columnas a float
df['Mkt-RF'] = df['Mkt-RF'].str.replace(',', '.').astype(float)
df['SMB'] = df['SMB'].str.replace(',', '.').astype(float)
df['HML'] = df['HML'].str.replace(',', '.').astype(float)

# Convierte las columnas de RF y rendimientos de apple de porcentaje a float
df['RF'] = df['RF'].str.rstrip('%').str.replace(',', '.').astype(float) / 100
df['rendimientos nvidia'] = df['rendimientos nvidia'].str.rstrip('%').str.replace(',', '.').astype(float) / 100

# Para % Fundflows, maneja los NaNs antes de la conversión si es necesario
df['% Fundflows'] = df['% Fundflows'].str.rstrip('%').str.replace(',', '.').astype(float) / 100

# Verifica los cambios
print(df.head())
print(df.dtypes)
# Out:
#         Date  Mkt-RF   SMB   HML     RF  rendimientos nvidia  % Fundflows  \
# 0 2018-03-01    0.59 -0.39 -0.18  0.006               0.0637      -0.0008
# 1 2018-04-01    0.42 -0.26  0.24  0.006               0.0053      -0.0036
# 2 2018-05-01    0.66 -0.35 -0.26  0.006               0.0084      -0.0019
# 3 2018-08-01    0.19 -0.15  0.05  0.006               0.0302      -0.0046
# 4 2018-09-01    0.15 -0.35 -0.04  0.006              -0.0004       0.0082
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN
# Date                   datetime64[ns]
# Mkt-RF                        float64
# SMB                           float64
# HML                           float64
# RF                            float64
# rendimientos nvidia           float64
# % Fundflows                   float64
# Unnamed: 7                    float64
# Unnamed: 8                    float64
# Unnamed: 9                    float64
# dtype: object

# %%
import statsmodels.api as sm

# Preparar las variables independientes
# Añadir una constante al modelo para el término de intercepción
X = df[['Mkt-RF', 'SMB', 'HML', '% Fundflows']]
X = sm.add_constant(X)

# La variable dependiente es el exceso de rendimiento de Apple
# Asegúrate de que 'RF' y 'rendimientos apple' están en formato decimal adecuado
Y = df['rendimientos nvidia'] - df['RF']

# Estimar el modelo OLS
modelo = sm.OLS(Y, X).fit()

# Mostrar el resumen del modelo
print(modelo.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.181
# Model:                            OLS   Adj. R-squared:                  0.179
# Method:                 Least Squares   F-statistic:                     83.25
# Date:                Tue, 19 Mar 2024   Prob (F-statistic):           6.25e-64
# Time:                        19:39:00   Log-Likelihood:                 3173.2
# No. Observations:                1514   AIC:                            -6336.
# Df Residuals:                    1509   BIC:                            -6310.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -0.0059      0.001     -7.733      0.000      -0.007      -0.004
# Mkt-RF          0.0101      0.001     17.206      0.000       0.009       0.011
# SMB            -0.0015      0.001     -1.319      0.187      -0.004       0.001
# HML            -0.0032      0.001     -4.376      0.000      -0.005      -0.002
# % Fundflows     0.1707      0.122      1.398      0.162      -0.069       0.410
# ==============================================================================
# Omnibus:                      159.322   Durbin-Watson:                   1.942
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1263.857
# Skew:                           0.028   Prob(JB):                    3.61e-275
# Kurtosis:                       7.476   Cond. No.                         215.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import pandas as pd
import statsmodels.api as sm

# Step 1: Convert the 'date' column to datetime if it's not already
df['Date'] = pd.to_datetime(df['Date'])

# Step 2: Filter the DataFrame for the desired date range
start_date = '2020-01-01'
end_date = '2023-12-31'
mask = (df['Date'] >= start_date) & (df['Date'] <= end_date)
filtered_df = df.loc[mask]

# Step 3: Prepare the independent variables, add a constant for the intercept
X = filtered_df[['Mkt-RF', 'SMB', 'HML', '% Fundflows']]
X = sm.add_constant(X)

# Ensure 'RF' and 'rendimientos nvidia' are in the correct decimal format
Y = filtered_df['rendimientos nvidia'] - filtered_df['RF']

# Estimate the OLS model
modelo = sm.OLS(Y, X).fit()

# Show the model summary
print(modelo.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.128
# Model:                            OLS   Adj. R-squared:                  0.124
# Method:                 Least Squares   F-statistic:                     36.84
# Date:                Tue, 19 Mar 2024   Prob (F-statistic):           8.94e-29
# Time:                        19:46:18   Log-Likelihood:                 2035.4
# No. Observations:                1011   AIC:                            -4061.
# Df Residuals:                    1006   BIC:                            -4036.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -0.0048      0.001     -4.653      0.000      -0.007      -0.003
# Mkt-RF          0.0081      0.001     11.497      0.000       0.007       0.009
# SMB            -0.0022      0.001     -1.642      0.101      -0.005       0.000
# HML            -0.0026      0.001     -3.164      0.002      -0.004      -0.001
# % Fundflows     0.1413      0.171      0.826      0.409      -0.194       0.477
# ==============================================================================
# Omnibus:                       75.906   Durbin-Watson:                   1.965
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              239.355
# Skew:                           0.330   Prob(JB):                     1.06e-52
# Kurtosis:                       5.290   Cond. No.                         252.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
